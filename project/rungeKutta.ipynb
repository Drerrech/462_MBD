# %%
from mbd_plots import * 

f_st = -12
t = 0.10
ticks = 200
alphaEnd = 8
lw = 4

colors = plt.cm.tab20.colors  


'''
Prof. Hare, please note:

- you will need to change the base directory if 
  you wish to plot these on your machine 

- the txt files will be included in the final submission

- see top of mbd_plots script for required package installation 

- if you wish to run a script, rather than this notebook cell,
  paste the contents of this cell into a new script

enjoy

'''




rk_base = "/Users/justindilabio/Desktop/462_MBD/runge_kutta_data_v2"

rk_basic_II_fb_paths = find_log_paths(rk_base, "basic_[I-I]_fb_300")
rk_basic_II_q_paths = find_log_paths(rk_base, "basic_[I-I]_q_300")
rk_basic_II_qv_paths = find_log_paths(rk_base, "basic_[I-I]_qv_300")

rk_basic_I_fb_paths = find_log_paths(rk_base, "basic_[I]_fb_300")
rk_basic_I_q_paths = find_log_paths(rk_base, "basic_[I]_q_300")
rk_basic_I_qv_paths = find_log_paths(rk_base, "basic_[I]_qv_300")

rk_basic_I_ei_fb_paths = find_log_paths(rk_base, "basic_[I]-ei_fb_300")
rk_basic_I_ei_q_paths = find_log_paths(rk_base, "basic_[I]-ei_q_300")
rk_basic_I_ei_qv_paths = find_log_paths(rk_base, "basic_[I]-ei_qv_300")

rk_v2_II_fb_paths = find_log_paths(rk_base, "v2_[I-I]_fb_300")
rk_v2_II_q_paths = find_log_paths(rk_base, "v2_[I-I]_q_300")
rk_v2_II_qv_paths = find_log_paths(rk_base, "v2_[I-I]_qv_300")

rk_v2_I_fb_paths = find_log_paths(rk_base, "v2_[I]_fb_300")
rk_v2_I_q_paths = find_log_paths(rk_base, "v2_[I]_q_300")
rk_v2_I_qv_paths = find_log_paths(rk_base, "v2_[I]_qv_300")

rk_v2_I_ei_fb_paths = find_log_paths(rk_base, "v2_[I]-ei_fb_300")
rk_v2_I_ei_q_paths = find_log_paths(rk_base, "v2_[I]-ei_q_300")
rk_v2_I_ei_qv_paths = find_log_paths(rk_base, "v2_[I]-ei_qv_300")

rk_v2_random_fb_paths = find_log_paths(rk_base, "v2_random_fb_300")
rk_v2_random_q_paths  = find_log_paths(rk_base, "v2_random_q_300")





# basic performance profiles

rk_basic_II_fb_perf      = perfProf(rk_basic_II_fb_paths, alphaTo= alphaEnd, alphaTicks= ticks, f_star = f_st, tao = t)
rk_basic_II_q_perf       = perfProf(rk_basic_II_q_paths, alphaTo= alphaEnd, alphaTicks= ticks,f_star= f_st, tao=t)
rk_basic_II_qv_perf      = perfProf(rk_basic_II_qv_paths,alphaTo= alphaEnd,alphaTicks= ticks, f_star= f_st, tao=t)

rk_basic_I_fb_perf = perfProf(rk_basic_I_fb_paths, alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)
rk_basic_I_q_perf  = perfProf(rk_basic_I_q_paths,alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)
rk_basic_I_qv_perf = perfProf(rk_basic_I_qv_paths, alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)

rk_basic_I_ei_fb_perf = perfProf(rk_basic_I_ei_fb_paths, alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)
rk_basic_I_ei_q_perf  = perfProf(rk_basic_I_ei_q_paths,alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)
rk_basic_I_ei_qv_perf = perfProf(rk_basic_I_ei_qv_paths, alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)


# v2 performance profiles



rk_v2_II_fb_perf      = perfProf(rk_v2_II_fb_paths, alphaTo= alphaEnd, alphaTicks= ticks,f_star = f_st, tao = t)
rk_v2_II_q_perf       = perfProf(rk_v2_II_q_paths, alphaTo= alphaEnd, alphaTicks= ticks,f_star= f_st, tao=t)
rk_v2_II_qv_perf      = perfProf(rk_v2_II_qv_paths,alphaTo= alphaEnd,alphaTicks= ticks, f_star= f_st, tao=t)

rk_v2_I_fb_perf = perfProf(rk_v2_I_fb_paths, alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)
rk_v2_I_q_perf  = perfProf(rk_v2_I_q_paths,alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)
rk_v2_I_qv_perf = perfProf(rk_v2_I_qv_paths, alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)

rk_v2_I_ei_fb_perf = perfProf(rk_v2_I_ei_fb_paths, alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)
rk_v2_I_ei_q_perf  = perfProf(rk_v2_I_ei_q_paths,alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)
rk_v2_I_ei_qv_perf = perfProf(rk_v2_I_ei_qv_paths, alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)



plt.figure(figsize=(11,6))



# basic 

plt.plot(rk_basic_II_fb_perf,drawstyle='steps-post', label="basic II fb",linewidth = lw ,color = colors[0])
plt.plot(rk_basic_II_q_perf, drawstyle='steps-post', label="basic II q perf",linewidth=lw,color = colors[19])
plt.plot(rk_basic_II_qv_perf,    drawstyle='steps-post',     label="basic II qv",linewidth=lw,color = colors[18])


plt.plot(rk_basic_II_fb_perf, drawstyle='steps-post',label="basic I fb",linewidth=lw,color = colors[17])
plt.plot(rk_basic_II_q_perf, drawstyle='steps-post', label="basic I q",linewidth=lw,color = colors[16])
plt.plot(rk_basic_II_qv_perf,drawstyle='steps-post', label="basic I qv",linewidth=lw,color = colors[15])



plt.plot(rk_basic_I_ei_fb_perf,drawstyle='steps-post',label="basic I ei fb",linewidth=lw,color = colors[14])
plt.plot(rk_basic_I_ei_q_perf, drawstyle='steps-post', label="basic I ei q",linewidth=lw,color = colors[13])
plt.plot(rk_basic_I_ei_qv_perf, drawstyle='steps-post',label="basic I ei qv",linewidth=lw,color = colors[12])




# v2
plt.plot(rk_v2_II_fb_perf,drawstyle='steps-post', label="v2 II fb",linewidth=lw,color = colors[11])
plt.plot(rk_v2_II_q_perf, drawstyle='steps-post', label="v2 II q perf",linewidth=lw,color = colors[10])
plt.plot(rk_v2_II_qv_perf,    drawstyle='steps-post',     label="v2 II qv",linewidth=lw,color = colors[9])

plt.plot(rk_v2_I_fb_perf, drawstyle='steps-post', label="v2 I fb",linewidth=lw,color = colors[8])
plt.plot(rk_v2_I_q_perf, drawstyle='steps-post', label="v2 I q",linewidth=lw,color = colors[7])
plt.plot(rk_v2_I_qv_perf,drawstyle='steps-post', label="v2 I qv",linewidth=lw,color = colors[6])

plt.plot(rk_v2_I_ei_fb_perf, drawstyle='steps-post', label="v2 I ei fb",linewidth=lw,color = colors[5])
plt.plot(rk_v2_I_ei_q_perf, drawstyle='steps-post', label="v2 I ei q",linewidth=lw,color = colors[4])
plt.plot(rk_v2_I_ei_qv_perf,drawstyle='steps-post', label="v2 I ei qv",linewidth=lw,color = colors[3])

plt.plot(rk_v2_I_fb_perf,drawstyle='steps-post',label="v2 random fb",linewidth=lw)
plt.plot(rk_v2_I_q_perf, drawstyle='steps-post', label="v2 random q",linewidth=lw)
plt.plot(rk_v2_I_qv_perf, drawstyle='steps-post',label="v2 random qv",linewidth=lw)

plt.plot(rk_basic_I_fb_perf,drawstyle='steps-post',label="basic random fb",linewidth=lw,color = colors[2])
plt.plot(rk_basic_I_q_perf, drawstyle='steps-post', label="basic random q",linewidth=lw,color = colors[1])
plt.plot(rk_basic_I_qv_perf, drawstyle='steps-post',label="basic random qv",linewidth=lw,color = colors[0])







plt.legend()

linewidth=3
plt.xlabel(r'$\alpha$')
plt.ylabel(r'$\rho_a(\alpha)$')
plt.ylim(0, 1)
plt.title('RK Performance Profile (τ = 10%) (All Variants)', fontsize=22)
plt.grid(True)
plt.show()
