# %%
from mbd_plots import * 

f_st = -20000
t = 0.4
ticks = 200
alphaEnd = 8
lw = 4


'''
Prof Hare, please note:

- you will need to change the base directory if you wish to plot these on your machine

- the txt files will be included in the final submission

- see top of mbd_plots script for required package installation 

- if you wish to run a script, rather than this notebook cell,
  paste the contents of this cell into a new script

enjoy

'''



ap_base = "/Users/justindilabio/Desktop/462_MBD/simplified_wing_data_v2"

ap_basic_II_fb_paths = find_log_paths(ap_base, "basic_[I-I]_fb_300")
ap_basic_II_q_paths = find_log_paths(ap_base, "basic_[I-I]_q_300")
ap_basic_II_qv_paths = find_log_paths(ap_base, "basic_[I-I]_qv_300")


#ap_basic_I_fb_paths = find_log_paths(ap_base, "basic_[I]_fb_300") DNE
ap_basic_I_q_paths = find_log_paths(ap_base, "basic_[I]_q_300")
ap_basic_I_qv_paths = find_log_paths(ap_base, "basic_[I]_qv_300")


ap_basic_I_ei_fb_paths = find_log_paths(ap_base, "basic_[I]-ei_fb_300")
ap_basic_I_ei_q_paths = find_log_paths(ap_base, "basic_[I]-ei_q_300")
ap_basic_I_ei_qv_paths = find_log_paths(ap_base, "basic_[I]-ei_qv_300")



ap_v2_II_fb_paths = find_log_paths(ap_base, "basic_[I-I]_fb_300")
ap_v2_II_q_paths = find_log_paths(ap_base, "basic_[I-I]_q_300")
ap_v2_II_qv_paths = find_log_paths(ap_base, "basic_[I-I]_qv_300")


ap_v2_I_fb_paths = find_log_paths(ap_base, "v2_[I]_fb_300")
ap_v2_I_q_paths = find_log_paths(ap_base, "v2_[I]_q_300")
ap_v2_I_qv_paths = find_log_paths(ap_base, "v2_[I]_qv_300")


ap_v2_I_ei_fb_paths = find_log_paths(ap_base, "v2_[I]-ei_fb_300")
ap_v2_I_ei_q_paths = find_log_paths(ap_base, "v2_[I]-ei_q_300")
ap_v2_I_ei_qv_paths = find_log_paths(ap_base, "v2_[I]-ei_qv_300")



ap_v2_random_fb_paths = find_log_paths(ap_base, "v2_random_fb_300")
ap_v2_random_q_paths  = find_log_paths(ap_base, "v2_random_q_300")



# basic performance profiles

ap_basic_II_fb_perf      = perfProf(ap_basic_II_fb_paths, alphaTo= alphaEnd, alphaTicks= ticks,f_star = f_st, tao = t)
ap_basic_II_q_perf       = perfProf(ap_basic_II_q_paths, alphaTo= alphaEnd, alphaTicks= ticks,f_star= f_st, tao=t)
ap_basic_II_qv_perf      = perfProf(ap_basic_II_qv_paths,alphaTo= alphaEnd,alphaTicks= ticks, f_star= f_st, tao=t)

#ap_basic_I_fb_perf = perfProf(ap_basic_I_fb_paths, alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t) DNE
ap_basic_I_q_perf  = perfProf(ap_basic_I_q_paths,alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)
ap_basic_I_qv_perf = perfProf(ap_basic_I_qv_paths, alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)

ap_basic_I_ei_fb_perf = perfProf(ap_basic_I_ei_fb_paths, alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)
ap_basic_I_ei_q_perf  = perfProf(ap_basic_I_ei_q_paths,alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)
ap_basic_I_ei_qv_perf = perfProf(ap_basic_I_ei_qv_paths, alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)


# v2 performance profiles

ap_v2_II_fb_perf      = perfProf(ap_v2_II_fb_paths, alphaTo= alphaEnd,alphaTicks= ticks, f_star = f_st, tao = t)
ap_v2_II_q_perf       = perfProf(ap_v2_II_q_paths, alphaTo= alphaEnd,alphaTicks= ticks, f_star= f_st, tao=t)
ap_v2_II_qv_perf      = perfProf(ap_v2_II_qv_paths,alphaTo= alphaEnd,alphaTicks= ticks, f_star= f_st, tao=t)

ap_v2_I_fb_perf = perfProf(ap_v2_I_fb_paths, alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)
ap_v2_I_q_perf  = perfProf(ap_v2_I_q_paths,alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)
ap_v2_I_qv_perf = perfProf(ap_v2_I_qv_paths, alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)

ap_v2_I_ei_fb_perf = perfProf(ap_v2_I_ei_fb_paths, alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)
ap_v2_I_ei_q_perf  = perfProf(ap_v2_I_ei_q_paths,alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)
ap_v2_I_ei_qv_perf = perfProf(ap_v2_I_ei_qv_paths, alphaTo= alphaEnd,alphaTicks= ticks,f_star= f_st, tao=t)



plt.figure(figsize=(alphaEnd,6))

# basic 
#DNEplt.plot(ap_basic_I_fb_perf, drawstyle='steps-post',label="basic I fb",linewidth=lw)#
plt.plot(ap_basic_I_q_perf, drawstyle='steps-post', label="basic I q",linewidth=lw)#
plt.plot(ap_basic_I_qv_perf,drawstyle='steps-post', label="basic I qv",linewidth=lw)#

plt.plot(ap_basic_II_fb_perf, drawstyle='steps-post',label="basic I-I fb",linewidth=lw)#
plt.plot(ap_basic_II_q_perf, drawstyle='steps-post', label="basic I-I q",linewidth=lw)#
plt.plot(ap_basic_II_qv_perf,drawstyle='steps-post', label="basic I-I qv",linewidth=lw)#

plt.plot(ap_basic_I_ei_fb_perf,drawstyle='steps-post',label="basic I ei fb",linewidth=lw)
plt.plot(ap_basic_I_ei_q_perf, drawstyle='steps-post', label="basic I ei q",linewidth=lw)#
plt.plot(ap_basic_I_ei_qv_perf, drawstyle='steps-post',label="basic I ei qv",linewidth=lw)#


#DNE plt.plot(ap_basic_I_fb_perf,drawstyle='steps-post',label="basic random fb",linewidth=lw)#
plt.plot(ap_basic_I_q_perf, drawstyle='steps-post', label="basic random q",linewidth=lw)
plt.plot(ap_basic_I_qv_perf, drawstyle='steps-post',label="basic random qv",linewidth=lw)#

# v2
plt.plot(ap_v2_II_fb_perf,drawstyle='steps-post', label="v2 I-I fb",linewidth=lw)#
plt.plot(ap_v2_II_q_perf, drawstyle='steps-post', label="v2 I-I q",linewidth=lw)#
plt.plot(ap_v2_II_qv_perf,drawstyle='steps-post',label="v2 I-I qv",linewidth=lw)#

plt.plot(ap_v2_I_fb_perf, drawstyle='steps-post', label="v2 Ifb",linewidth=lw)
plt.plot(ap_v2_I_q_perf, drawstyle='steps-post', label="v2 I q",linewidth=lw)
plt.plot(ap_v2_I_qv_perf,drawstyle='steps-post', label="v2 I qv perf",linewidth=lw)#

plt.plot(ap_v2_I_ei_fb_perf, drawstyle='steps-post', label="v2 I ei fb",linewidth=lw)#
plt.plot(ap_v2_I_ei_q_perf, drawstyle='steps-post', label="v2 I ei q",linewidth=lw)#
plt.plot(ap_v2_I_ei_qv_perf,drawstyle='steps-post', label="v2 I ei qv",linewidth=lw)#

plt.plot(ap_v2_I_fb_perf,drawstyle='steps-post',label="v2 random fb",linewidth=lw)#
plt.plot(ap_v2_I_q_perf, drawstyle='steps-post', label="v2 random q",linewidth=lw)
plt.plot(ap_v2_I_qv_perf, drawstyle='steps-post',label="v2 random qv",linewidth=lw)#

plt.legend()

linewidth=3

plt.xlabel(r'$\alpha$')
plt.ylabel(r'$\rho_a(\alpha)$')
plt.ylim(0, 1)
plt.title('Plane Wing Performance Profile')
plt.grid(True)
plt.show()
